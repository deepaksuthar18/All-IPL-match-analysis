# %%
#Q1. find toh five head team?
#Q2. find how many play the perticular vanue/ground count?
#Q3. Which team have most top five match  win in the IPL?

# %%
import pandas as pd

data = pd.read_excel("Copy of All_IPL_Match_Scores_easy(2).xlsx")
data
# Out:
#      Match_Number               Match    Date  Year      Venue  \
# 0             391        League Match  May 18  2013  Bangalore
# 1             352        League Match  Apr 23  2013  Bangalore
# 2             147        League Match   Apr 3  2010    Chennai
# 3             507        League Match  May 15  2015  Hyderabad
# 4               2        League Match  Apr 19  2008     Mohali
# ..            ...                 ...     ...   ...        ...
# 509           411        League Match  Apr 26  2014  Abu Dhabi
# 510           125        League Match  Mar 18  2010  Bangalore
# 511           174  3rd Place Play-off  Apr 24  2010     Mumbai
# 512            38        League Match  May 16  2008     Mumbai
# 513           369        League Match   May 4  2013  Hyderabad
#
#     Team_Batting_First Team_Batting_Second  Bat_First_Runs_Scored  \
# 0            Bangalore             Chennai                    106
# 1            Bangalore                Pune                    263
# ...

# %%
df.head(5)
# Out:
#    Match_Number         Match    Date  Year      Venue Team_Batting_First  \
# 0           391  League Match  May 18  2013  Bangalore          Bangalore
# 1           352  League Match  Apr 23  2013  Bangalore          Bangalore
# 2           147  League Match   Apr 3  2010    Chennai            Chennai
# 3           507  League Match  May 15  2015  Hyderabad          Hyderabad
# 4             2  League Match  Apr 19  2008     Mohali            Chennai
#
#   Team_Batting_Second  Bat_First_Runs_Scored  Bat_First_Wickets_Lost  \
# 0             Chennai                    106                       2
# 1                Pune                    263                       5
# 2           Rajasthan                    246                       5
# 3           Bangalore                    135                       3
# 4              Punjab                    240                       5
#
#    Bat_First_Overs_Consumed  ...  Bat_Second_10_ov_score  \
# ...

# %%
df = data.groupby("Venue").Venue.count()
print(df)
# Out:
# Venue
# Abu Dhabi          7
# Ahmedabad         12
# Bangalore         47
# Bloemfontein       2
# Cape Town          7
# Centurion         12
# Chennai           48
# Cuttack            7
# Delhi             45
# Dharamsala         9
# Dubai              7
# Durban            15
# East London        3
# Hyderabad         34
# Indore             2
# Jaipur            33
# Johannesburg       8
# Kimberley          3
# Kochi              5
# Kolkata           47
# Mohali            35
# Mumbai            62
# Mumbai (BS)       11
# Nagpur             3
# Port Elizabeth     7
# Pune              21
# Raipur             4
# Ranchi             7
# Sharjah            6
# Visakhapatnam      5
# Name: Venue, dtype: int64

# %%
df = data.groupby("Venue").Venue.count().sort_values(ascending=False).head(5)
print(df)
# Out:
# Venue
# Mumbai       62
# Chennai      48
# Kolkata      47
# Bangalore    47
# Delhi        45
# Name: Venue, dtype: int64

# %%
# Filter to include only matches where the team batting first won
batting_first_wins = data[data['Team_Batting_First'] == data['Winner']]

# Filter to include only matches where the team batting first won
wins_by_team = batting_first_wins.groupby('Team_Batting_First').size()

# Sort the teams by the number of wins in descending order
sorted_wins_by_team = wins_by_team.sort_values(ascending=False)

# Display the top 5 teams with the most wins when batting first
print(sorted_wins_by_team.head(5))
# Out:
# Team_Batting_First
# Chennai      45
# Mumbai       41
# Hyderabad    31
# Kolkata      25
# Punjab       25
# dtype: int64
